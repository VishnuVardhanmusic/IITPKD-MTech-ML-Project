# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingClassifier
from catboost import CatBoostClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.neighbors import NearestCentroid

# %%
def GetModel():
    Models = []
    Models.append(('GBM'  , GradientBoostingClassifier()))
    Models.append(('CatBoost', CatBoostClassifier(silent=True)))
    Models.append(('LDA'  , LinearDiscriminantAnalysis()))
    Models.append(('QDA'  , QuadraticDiscriminantAnalysis()))
    Models.append(('NC'   , NearestCentroid()))
    return Models

def classification_metrics(model, X_train, y_train, X_test, y_test, y_pred):
    print(f"Training Accuracy Score: {model.score(X_train, y_train) * 100:.1f}")
    print(f"Testing Accuracy Score: {model.score(X_test, y_test) * 100:.1f}")
    print(classification_report(y_test, y_pred))

# %%
df = pd.read_csv('Crop_recommendation.csv')

# %%
target = 'label'
X_train, X_test, y_train, y_test = train_test_split(df.drop(target, axis=1), df[target], test_size=0.4, random_state=0)
models = GetModel()

for name, model in models:
    print(f"\n\nMachine Learning Model used is {name}")
    pipeline = make_pipeline(StandardScaler(), model)
    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_test)
    classification_metrics(pipeline, X_train, y_train, X_test, y_test, y_pred)
# Out:
# Machine Learning Model used is GBM
# Training Accuracy Score: 100.0
# Testing Accuracy Score: 98.5
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        40
#       banana       1.00      1.00      1.00        42
#    blackgram       0.95      0.97      0.96        40
#     chickpea       1.00      1.00      1.00        42
#      coconut       1.00      1.00      1.00        39
#       coffee       1.00      0.97      0.99        39
#       cotton       0.97      1.00      0.99        37
#       grapes       1.00      1.00      1.00        36
#         jute       0.86      0.97      0.91        37
#  kidneybeans       1.00      1.00      1.00        38
#       lentil       1.00      0.95      0.97        37
#        maize       0.95      0.97      0.96        40
#        mango       1.00      1.00      1.00        34
#    mothbeans       0.98      0.95      0.97        44
#     mungbean       1.00      1.00      1.00        34
#    muskmelon       1.00      1.00      1.00        38
#       orange       1.00      1.00      1.00        44
#       papaya       1.00      0.94      0.97        50
#   pigeonpeas       1.00      0.97      0.99        39
#  pomegranate       1.00      1.00      1.00        51
#         rice       0.98      0.98      0.98        45
#   watermelon       1.00      1.00      1.00        34
#
#     accuracy                           0.99       880
#    macro avg       0.99      0.99      0.99       880
# weighted avg       0.99      0.99      0.99       880
#
#
#
# Machine Learning Model used is CatBoost
# Training Accuracy Score: 100.0
# Testing Accuracy Score: 99.2
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        40
#       banana       1.00      1.00      1.00        42
#    blackgram       1.00      1.00      1.00        40
#     chickpea       1.00      1.00      1.00        42
#      coconut       1.00      1.00      1.00        39
#       coffee       1.00      1.00      1.00        39
#       cotton       1.00      1.00      1.00        37
#       grapes       1.00      1.00      1.00        36
#         jute       0.90      0.95      0.92        37
#  kidneybeans       1.00      1.00      1.00        38
#       lentil       1.00      0.97      0.99        37
#        maize       1.00      1.00      1.00        40
#        mango       1.00      1.00      1.00        34
#    mothbeans       0.98      1.00      0.99        44
#     mungbean       1.00      1.00      1.00        34
#    muskmelon       1.00      1.00      1.00        38
#       orange       1.00      1.00      1.00        44
#       papaya       1.00      1.00      1.00        50
#   pigeonpeas       1.00      1.00      1.00        39
#  pomegranate       1.00      1.00      1.00        51
#         rice       0.95      0.91      0.93        45
#   watermelon       1.00      1.00      1.00        34
#
#     accuracy                           0.99       880
#    macro avg       0.99      0.99      0.99       880
# weighted avg       0.99      0.99      0.99       880
#
#
#
# Machine Learning Model used is LDA
# Training Accuracy Score: 97.2
# Testing Accuracy Score: 96.1
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        40
#       banana       0.98      1.00      0.99        42
#    blackgram       0.88      0.90      0.89        40
#     chickpea       1.00      1.00      1.00        42
#      coconut       1.00      0.97      0.99        39
#       coffee       1.00      1.00      1.00        39
#       cotton       0.95      1.00      0.97        37
#       grapes       1.00      1.00      1.00        36
#         jute       0.78      0.97      0.87        37
#  kidneybeans       0.93      1.00      0.96        38
#       lentil       0.86      0.97      0.91        37
#        maize       1.00      0.95      0.97        40
#        mango       0.94      1.00      0.97        34
#    mothbeans       1.00      0.89      0.94        44
#     mungbean       1.00      1.00      1.00        34
#    muskmelon       1.00      1.00      1.00        38
#       orange       1.00      1.00      1.00        44
#       papaya       1.00      0.92      0.96        50
#   pigeonpeas       1.00      0.85      0.92        39
#  pomegranate       0.98      1.00      0.99        51
#         rice       0.90      0.78      0.83        45
#   watermelon       1.00      1.00      1.00        34
#
#     accuracy                           0.96       880
#    macro avg       0.96      0.96      0.96       880
# weighted avg       0.96      0.96      0.96       880
#
#
#
# Machine Learning Model used is QDA
# Training Accuracy Score: 99.6
# Testing Accuracy Score: 98.9
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        40
#       banana       1.00      1.00      1.00        42
#    blackgram       1.00      1.00      1.00        40
#     chickpea       1.00      1.00      1.00        42
#      coconut       1.00      1.00      1.00        39
#       coffee       1.00      1.00      1.00        39
#       cotton       0.97      0.95      0.96        37
#       grapes       1.00      1.00      1.00        36
#         jute       0.90      0.95      0.92        37
#  kidneybeans       1.00      1.00      1.00        38
#       lentil       1.00      0.97      0.99        37
#        maize       0.95      0.97      0.96        40
#        mango       1.00      1.00      1.00        34
#    mothbeans       0.98      1.00      0.99        44
#     mungbean       1.00      1.00      1.00        34
#    muskmelon       1.00      1.00      1.00        38
#       orange       1.00      1.00      1.00        44
#       papaya       1.00      1.00      1.00        50
#   pigeonpeas       1.00      1.00      1.00        39
#  pomegranate       1.00      1.00      1.00        51
#         rice       0.95      0.91      0.93        45
#   watermelon       1.00      1.00      1.00        34
#
#     accuracy                           0.99       880
#    macro avg       0.99      0.99      0.99       880
# weighted avg       0.99      0.99      0.99       880
#
#
#
# Machine Learning Model used is NC
# Training Accuracy Score: 88.8
# Testing Accuracy Score: 84.7
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        40
#       banana       1.00      1.00      1.00        42
#    blackgram       0.61      0.90      0.73        40
#     chickpea       1.00      0.95      0.98        42
#      coconut       0.93      0.97      0.95        39
#       coffee       1.00      1.00      1.00        39
#       cotton       0.97      0.92      0.94        37
#       grapes       1.00      1.00      1.00        36
#         jute       0.70      1.00      0.82        37
#  kidneybeans       0.84      1.00      0.92        38
#       lentil       0.81      0.68      0.74        37
#        maize       0.97      0.97      0.97        40
#        mango       0.61      0.91      0.73        34
#    mothbeans       0.60      0.27      0.38        44
#     mungbean       0.72      1.00      0.84        34
#    muskmelon       1.00      1.00      1.00        38
#       orange       0.61      0.50      0.55        44
#       papaya       0.82      0.66      0.73        50
#   pigeonpeas       1.00      0.69      0.82        39
#  pomegranate       0.80      0.73      0.76        51
#         rice       0.89      0.73      0.80        45
#   watermelon       0.92      1.00      0.96        34
#
#     accuracy                           0.85       880
#    macro avg       0.86      0.86      0.85       880
# weighted avg       0.85      0.85      0.84       880
