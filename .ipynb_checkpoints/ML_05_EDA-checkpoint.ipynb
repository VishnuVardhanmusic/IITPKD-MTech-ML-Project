# %%
import pandas as pd

# %%
df = pd.read_csv('crop_yield_dataset/yield_df.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     Area         Item  Year  hg/ha_yield  \
# 0           0  Albania        Maize  1990        36613
# 1           1  Albania     Potatoes  1990        66667
# 2           2  Albania  Rice, paddy  1990        23333
# 3           3  Albania      Sorghum  1990        12500
# 4           4  Albania     Soybeans  1990         7000
#
#    average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                         1485.0              121.0     16.37
# 1                         1485.0              121.0     16.37
# 2                         1485.0              121.0     16.37
# 3                         1485.0              121.0     16.37
# 4                         1485.0              121.0     16.37

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                       0
# Area                             0
# Item                             0
# Year                             0
# hg/ha_yield                      0
# average_rain_fall_mm_per_year    0
# pesticides_tonnes                0
# avg_temp                         0
# dtype: int64

# %%
df.describe()
# Out:
#          Unnamed: 0          Year    hg/ha_yield  \
# count  28242.000000  28242.000000   28242.000000
# mean   14120.500000   2001.544296   77053.332094
# std     8152.907488      7.051905   84956.612897
# min        0.000000   1990.000000      50.000000
# 25%     7060.250000   1995.000000   19919.250000
# 50%    14120.500000   2001.000000   38295.000000
# 75%    21180.750000   2008.000000  104676.750000
# max    28241.000000   2013.000000  501412.000000
#
#        average_rain_fall_mm_per_year  pesticides_tonnes      avg_temp
# count                    28242.00000       28242.000000  28242.000000
# mean                      1149.05598       37076.909344     20.542627
# std                        709.81215       59958.784665      6.312051
# min                         51.00000           0.040000      1.300000
# 25%                        593.00000        1702.000000     16.702500
# 50%                       1083.00000       17529.440000     21.510000
# ...

# %% [markdown]
# DATA CLEANING AND TRANSFORMATION

# %%
df.rename(columns={"hg/ha_yield":"yield","Item":"crop"}, inplace=True)
df["yield"] = df["yield"].astype("float64")
df["average_rain_fall_mm_per_year"] = df["average_rain_fall_mm_per_year"].astype("float64")

# %%
print(df.dtypes)
# Out:
# Unnamed: 0                         int64
# Area                              object
# crop                              object
# Year                               int64
# yield                            float64
# average_rain_fall_mm_per_year    float64
# pesticides_tonnes                float64
# avg_temp                         float64
# dtype: object

# %%
df.describe(include='object')
# Out:
#          Area      crop
# count   28242     28242
# unique    101        10
# top     India  Potatoes
# freq     4048      4276

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('crop').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
numerical_columns = ['Year', 'yield', 'average_rain_fall_mm_per_year', 'pesticides_tonnes', 'avg_temp']

for col in numerical_columns:
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    fig.suptitle(f'Distribution and Skewness of {col}', fontsize=16)
    sns.histplot(df[col], kde=True, ax=axes[0])
    axes[0].set_title(f'Histogram of {col}')
    sns.boxplot(x=df[col], ax=axes[1])
    axes[1].set_title(f'Box Plot of {col}')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# CHECKING FOR CORRELATION

# %%
numerical_columns = ['Year', 'yield', 'average_rain_fall_mm_per_year', 'pesticides_tonnes', 'avg_temp']
correlation = df[numerical_columns].corr()

print(correlation['yield'].sort_values(ascending=False))

# Plotting the correlation matrix as a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt=".2f", square=True, cbar_kws={"shrink": .8})
plt.title('Correlation Matrix for Numerical Columns')
plt.show()
# Out:
# yield                            1.000000
# Year                             0.091630
# pesticides_tonnes                0.064085
# average_rain_fall_mm_per_year    0.000962
# avg_temp                        -0.114777
# Name: yield, dtype: float64

# %% [raw]
# We can infer,
# hg/ha_yield (1.000000): This is the correlation of the target variable with itself and is always 1
#
# Year (0.091630): There is a small positive correlation between the year and the crop yield (hg/ha_yield). This suggests that crop yield slightly increases over time, but the relationship is weak.
#
# Pesticides_tonnes (0.064085): There is a very weak positive correlation between the amount of pesticides used and the crop yield. This indicates that an increase in pesticide usage has a very slight association with an increase in yield, but it's not a strong relationship.
#
# average_rain_fall_mm_per_year (0.000962): This correlation is nearly zero, meaning there's no noticeable relationship between rainfall and crop yield in this data. Rainfall doesn't seem to impact the yield based on this correlation significantly.
#
# avg_temp (-0.114836): This is a weak negative correlation between average temperature and crop yield. It suggests that as the temperature increases the crop yield slightly decreases
