# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

# %%
df = pd.read_csv('Crop_recommendation.csv')

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %% [markdown]
# CHECKING WHETHER DATA IS BALANCED OR INBALANCED

# %%
sns.countplot(y='label',data=df)
# Out:
# <Axes: xlabel='count', ylabel='label'>

# %% [raw]
# WE CAN INFER THAT ALL LABELS ARE UNIFORMLY SPREAD, HENCE BALANCED DATASET

# %% [markdown]
# MODEL BUILDING AND FITTING IT TO THE GIVEN DATASET

# %% [markdown]
# # Classification using K Nearest Neighbors Classifier

# %%
#making X and Y components i.e Independent features/attributes and Target variable
c=df.label.astype('category')
trgts = dict(enumerate(c.cat.categories))
df['target'] = c.cat.codes

y=df.target
X = df[['N','P','K','temperature','humidity','ph','rainfall']]

# %%
trgts
# Out:
# {0: 'apple',
#  1: 'banana',
#  2: 'blackgram',
#  3: 'chickpea',
#  4: 'coconut',
#  5: 'coffee',
#  6: 'cotton',
#  7: 'grapes',
#  8: 'jute',
#  9: 'kidneybeans',
#  10: 'lentil',
#  11: 'maize',
#  12: 'mango',
#  13: 'mothbeans',
#  14: 'mungbean',
#  15: 'muskmelon',
#  16: 'orange',
#  17: 'papaya',
#  18: 'pigeonpeas',
#  19: 'pomegranate',
#  20: 'rice',
#  21: 'watermelon'}

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=1)

# %%
#Performing Min Max Scaling to bring all the input features to the same scale
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
#k-NN classifier

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train_scaled,y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(X_test_scaled,y_test)
# Out:
# 0.9781818181818182

# %%
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(y_test,knn.predict(X_test_scaled))
df_cm = pd.DataFrame(mat, list(trgts.values()), list(trgts.values()))
plt.figure(figsize = (12,8))
sns.heatmap(df_cm, annot = True, cmap='terrain')
# Out:
# <Axes: >

# %% [raw]
# Now, let us view for varying the k value in KNN Classifier, what is the variation in accuracy
# Which k value is best recommended

# %%
scores = []

for k in range(1,11):
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train_scaled,y_train)
    scores.append(knn.score(X_test_scaled,y_test))

# %%
for i in range(len(scores)):
    print("The Accuracy of KNN with k value " + str(i+1) + " is: " + str(scores[i]))
# Out:
# The Accuracy of KNN with k value 1 is: 0.9763636363636363
# The Accuracy of KNN with k value 2 is: 0.98
# The Accuracy of KNN with k value 3 is: 0.98
# The Accuracy of KNN with k value 4 is: 0.9818181818181818
# The Accuracy of KNN with k value 5 is: 0.9781818181818182
# The Accuracy of KNN with k value 6 is: 0.98
# The Accuracy of KNN with k value 7 is: 0.9727272727272728
# The Accuracy of KNN with k value 8 is: 0.98
# The Accuracy of KNN with k value 9 is: 0.98
# The Accuracy of KNN with k value 10 is: 0.9818181818181818

# %%
k_range = range(1,11)
plt.xlabel('K Value')
plt.ylabel('Accuracy')
plt.scatter(k_range, scores)
plt.vlines(k_range,0, scores, label = scores)
plt.ylim(0.96,0.99)
plt.xticks([i for i in range(1,11)]);

# %% [markdown]
# Performing Label Encoding to assign numerical values to each crop label

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
label_encoder = LabelEncoder()
features = df.columns[:-2]
X = df[features]
y = label_encoder.fit_transform(df["label"])
print(X.shape,y.shape)
# Out:
# (2200, 7) (2200,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X.values, y, test_size = 0.2, random_state = 0)
print(f"Train Data: {X_train.shape}, {y_train.shape}")
print(f"Train Data: {X_test.shape}, {y_test.shape}")
# Out:
# Train Data: (1760, 7), (1760,)
# Train Data: (440, 7), (440,)

# %%
#Performing multiple times k-NN with increasing K Value and examining the error rates

from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score, confusion_matrix
error_rate = []
for i in range(1, 50):
    pipeline = make_pipeline(StandardScaler(), KNeighborsClassifier(n_neighbors = i))
    pipeline.fit(X_train, y_train)
    predictions = pipeline.predict(X_test)
    accuracy = accuracy_score(y_test, predictions)
    error_rate.append(np.mean(predictions != y_test))

# %%
plt.figure(figsize=(16,6))
plt.plot(range(1,50),error_rate,color='blue', linestyle='dashed', marker='o')
plt.title('Viewing Error Rate Variation upon increase of K Value')
plt.xlabel('K Value')
plt.xticks(range(1,50))
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
print("Minimum Error is",str(round(min(error_rate),4)),"at K =",error_rate.index(min(error_rate))+1)

print("Maximum Error is",str(round(max(error_rate),4)),"at K =",error_rate.index(max(error_rate))+1)
# Out:
# Minimum Error is 0.0205 at K = 4
# Maximum Error is 0.1182 at K = 44

# %% [markdown]
# # Classification using Support Vector Classifer (SVC)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=1)
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

svc_linear = SVC(kernel = 'linear').fit(X_train_scaled, y_train)
print("Linear Kernel Accuracy: ",svc_linear.score(X_test_scaled,y_test))

svc_rbf = SVC(kernel = 'rbf').fit(X_train_scaled, y_train)
print("RBF Kernel Accuracy: ", svc_rbf.score(X_test_scaled,y_test))

svc_poly = SVC(kernel = 'poly').fit(X_train_scaled, y_train)
print("Polynomial Kernel Accuracy: ", svc_poly.score(X_test_scaled,y_test))
# Out:
# Linear Kernel Accuracy:  0.9745454545454545
# RBF Kernel Accuracy:  0.9872727272727273
# Polynomial Kernel Accuracy:  0.9890909090909091

# %% [raw]
# Now, performing HYPERPARAMETER TUNING
# via GridSearchCV (Brute force searching for getting the best parameter)

# %%
from sklearn.model_selection import GridSearchCV

parameters = {'C': np.logspace(-3,2,6).tolist(), 'gamma': np.logspace(-3,2,6).tolist()}
model = GridSearchCV(estimator = SVC(kernel = 'linear'), param_grid=parameters, n_jobs = -1, cv = 4)
model.fit(X_train_scaled,y_train)
# Out:
# GridSearchCV(cv=4, estimator=SVC(kernel='linear'), n_jobs=-1,
#              param_grid={'C': [0.001, 0.01, 0.1, 1.0, 10.0, 100.0],
#                          'gamma': [0.001, 0.01, 0.1, 1.0, 10.0, 100.0]})

# %%
print("Accuracy of Linear Kernel SVM before tuning is "+str(svc_linear.score(X_test_scaled,y_test)))

print("Accuracy of Linear Kernel SVM after tuning is "+str(model.best_score_ ))
# Out:
# Accuracy of Linear Kernel SVM before tuning is 0.9745454545454545
# Accuracy of Linear Kernel SVM after tuning is 0.985457462563765

# %%
parameters = {'C': np.logspace(-4,5,7).tolist(), 'gamma': np.logspace(-4,5,7).tolist()}
model = GridSearchCV(estimator = SVC(kernel = 'rbf'), param_grid=parameters, n_jobs = -1, cv = 4)
model.fit(X_train_scaled,y_train)
# Out:
# GridSearchCV(cv=4, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.0001, 0.0031622776601683794, 0.1,
#                                3.1622776601683795, 100.0, 3162.2776601683795,
#                                100000.0],
#                          'gamma': [0.0001, 0.0031622776601683794, 0.1,
#                                    3.1622776601683795, 100.0,
#                                    3162.2776601683795, 100000.0]})

# %%
print("Accuracy of RBF Kernel SVM before tuning is "+str(svc_rbf.score(X_test_scaled,y_test)))

print("Accuracy of RBF Kernel SVM after tuning is "+str(model.best_score_ ))
# Out:
# Accuracy of RBF Kernel SVM before tuning is 0.9872727272727273
# Accuracy of RBF Kernel SVM after tuning is 0.9909098121723594

# %%
parameters = {'C': np.logspace(-1,8,8).tolist(), 'gamma': np.logspace(-1,8,8).tolist()}
model = GridSearchCV(estimator = SVC(kernel = 'poly'), param_grid=parameters, n_jobs = -1, cv = 4)
model.fit(X_train_scaled,y_train)
# Out:
# GridSearchCV(cv=4, estimator=SVC(kernel='poly'), n_jobs=-1,
#              param_grid={'C': [0.1, 1.9306977288832505, 37.27593720314942,
#                                719.6856730011528, 13894.954943731389,
#                                268269.57952797273, 5179474.679231224,
#                                100000000.0],
#                          'gamma': [0.1, 1.9306977288832505, 37.27593720314942,
#                                    719.6856730011528, 13894.954943731389,
#                                    268269.57952797273, 5179474.679231224,
#                                    100000000.0]})

# %%
print("Accuracy of Polynomial Kernel SVM before tuning is "+str(svc_poly.score(X_test_scaled,y_test)))

print("Accuracy of Polynomial Kernel SVM after tuning is "+str(model.best_score_ ))
# Out:
# Accuracy of Polynomial Kernel SVM before tuning is 0.9890909090909091
# Accuracy of Polynomial Kernel SVM after tuning is 0.9878817085498014
